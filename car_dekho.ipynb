# %%
import pandas as pd
import numpy as np
import  seaborn as sns

# %%
df=pd.read_csv("cardekho_dataset.csv")

# %%
df.columns

# %%
df=df.drop(columns='Unnamed: 0',axis=1)

# %%
df.shape

# %%
df.head()

# %%
df.isna().sum()

# %%
df.dtypes

# %%
df.describe()

# %%
#check duplicates
df[df.duplicated()]

# %%
df.duplicated().sum()

# %%
df.shape

# %%
#drop duplicates
df.drop_duplicates(inplace=True)

# %%
df.shape

# %%
df.columns

# %%
df.dtypes

# %%
categorivcal_features=[feature for feature in df.columns if df[feature].dtype=='O']

# %%
categorivcal_features

# %%
Numerical_features=[feature for feature in df.columns if df[feature].dtype!='O']

# %%
Numerical_features

# %%
df.brand.value_counts()

# %%
df['brand'].value_counts()[:10].plot.bar()
# Out:
# <Axes: xlabel='brand'>

# %%
df.seller_type.value_counts()

# %%
df.transmission_type.unique()

# %%
[df.groupby(['brand','transmission_type'])['mileage'].sum()]
# Out:
# [brand          transmission_type
#  Audi           Automatic             3062.75
#  BMW            Automatic             7608.22
#  Bentley        Automatic               24.10
#  Datsun         Automatic              219.16
#                 Manual                3387.50
#  Ferrari        Automatic                4.00
#  Force          Manual                  17.00
#  Ford           Automatic             1102.62
#                 Manual               14394.36
#  Honda          Automatic             4896.20
#                 Manual               24478.36
#  Hyundai        Automatic             6848.53
#                 Manual               50983.07
#  ISUZU          Automatic               27.60
#  Isuzu          Automatic               13.80
#                 Manual                  74.40
#  Jaguar         Automatic              932.94
#  Jeep           Automatic              162.20
#                 Manual                 503.50
#  Kia            Automatic              210.64
# ...

# %%
sns.histplot(df['vehicle_age'],kde=True,color='m')
# Out:
# <Axes: xlabel='vehicle_age', ylabel='Count'>

# %%
import matplotlib.pyplot as plt
plt.pie(df.fuel_type.value_counts(),labels=df.fuel_type.value_counts().index,autopct="%1.1f%%")
plt.legend()
plt.title('Fule')
plt.show()

# %%
Numerical_features
# Out:
# ['vehicle_age',
#  'km_driven',
#  'mileage',
#  'engine',
#  'max_power',
#  'seats',
#  'selling_price']

# %%
sns.boxplot(df['engine'])
# Out:
# <Axes: ylabel='engine'>

# %%
df.hist(bins=100,figsize=(20,24),color='blue')
# Out:
# array([[<Axes: title={'center': 'vehicle_age'}>,
#         <Axes: title={'center': 'km_driven'}>,
#         <Axes: title={'center': 'mileage'}>],
#        [<Axes: title={'center': 'engine'}>,
#         <Axes: title={'center': 'max_power'}>,
#         <Axes: title={'center': 'seats'}>],
#        [<Axes: title={'center': 'selling_price'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
sns.countplot(df,x='seats',hue='transmission_type')
# Out:
# <Axes: xlabel='seats', ylabel='count'>
